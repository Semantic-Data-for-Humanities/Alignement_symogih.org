# %% [markdown]
# # Automatically produce issues...
#
# ...for the TyIn in the Symogih.org ontology, according to the RDFs ontology schema.
#
# Some cells originate from [graph_to_ontome.ipynb](https://github.com/Semantic-Data-for-Humanities/OntoME_importer/blob/main/graph_to_ontome.ipynb), despite some adaptation:
# * cell n°4 (open and parse RDF file),
# * cell n°6 (find and record TyIn informations).
#
# ## Declarations

# %%
from tqdm.notebook import tqdm #tqdm gives a progression bar to for loops.
from datetime import datetime
from itertools import chain
import json
import numpy as np
import rdflib
import requests
import time

file = "sources/xml_symogih.xml"

# %% [markdown]
# ## Parse RDF schema

# %%
### Open and import file.
try:
    g = rdflib.Graph()
    g.parse(file, format="xml")
    
    # Prepare namespace declarations.
    ns_decl_list = []
    
    # Prepare checks.
    typed_decls = {}
    typelist = []
    for s, p, o in g.triples((None, rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), None)):

        # These elements will have different values when they're dealt with.
        typed_decls[s] = "no"
        typelist.append(o)
    print("These rdf:type objects were detected :\n")
    print(np.unique(typelist))
    
except Exception as e:
    print('Error: ' + str(e))
# Out:
# These rdf:type objects were detected :
#
# ['http://www.w3.org/2002/07/owl#Class'
#  'http://www.w3.org/2002/07/owl#ObjectProperty'
#  'http://www.w3.org/2002/07/owl#Ontology']

# %% [markdown]
# ## Get simple TyIn information

# %%
### Test the recovery of 'classes',
# as well as the predicates of which they are subjects.

tyin = {}
cpredispo = [
    "http://www.w3.org/1999/02/22-rdf-syntax-ns#type",
    "http://www.w3.org/2000/01/rdf-schema#comment",
    "http://www.w3.org/2000/01/rdf-schema#isDefinedBy",
    "http://www.w3.org/2000/01/rdf-schema#label",
    "http://www.w3.org/2000/01/rdf-schema#subClassOf",
    "http://www.w3.org/2002/07/owl#equivalentClass",
    "http://www.w3.org/2002/07/owl#unionOf"
]
cpredicates = []

# Get the predicates.
for s, p, o in g.triples((None, rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))):
    if 'TyIn' in str(s):
        tyin[s] = {}
        for so, po, oo in g.triples((s, None, None)):
            cpredicates.append(po)
            if po in tyin[s].keys():
                tyin[s][po].append(so)
            else:
                tyin[s][po] = [oo]

# Direct output.
print(f"There are {len(tyin.keys())} 'TyIn'.\n")

print("These are the associated properties :\n\t")
    
for p in np.unique(cpredicates):
    print("\t", p)
# Out:
# There are 133 'TyIn'.
#
# These are the associated properties :
#
# 	 http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 	 http://www.w3.org/2000/01/rdf-schema#comment
# 	 http://www.w3.org/2000/01/rdf-schema#label
# 	 http://www.w3.org/2000/01/rdf-schema#subClassOf
# 	 http://www.w3.org/2004/02/skos/core#notation

# %% [markdown]
# ## Add relationship information

# %%
for inftype in tyin.keys():
    ident = inftype.split('/')[-1]
    altident = ident + "_"
    
    local = {}
    
    for s, p, o in g.triples((None, None, None)):
        subjident = str(s).split('/')[-1]
        if subjident != ident :
            if subjident.endswith(ident) == True or subjident.startswith(altident):
                if s in local.keys():
                    local[s][p] = o
                else:
                    local[s] = {p:o}
            
    tyin[inftype]['to_table'] = local

# %% [markdown]
# ## Initiate progress logs

# %%
dont_post = [
    'TyIn6',
    'TyIn3',
    'TyIn7',
    'TyIn11',
    'TyIn1',
    'TyIn2',
    'TyIn12',
    'TyIn130',
    'TyIn13',
    'TyIn55'
]
posted = []
failed = []

# %% [markdown]
# ## Create and post issue contents

# %%
issues = {}

# Token removed for discretion.
token = ""

# After script execution,
# repository will be transferred to original owner:
# Semantic-Data-for-Humanitites.
owner = "MPica"

repo = "Alignement_symogih.org"

url = f"https://api.github.com/repos/{owner}/{repo}/issues"
headers = {
    "Authorization" : f"token {token}",
    "accept":"application/vnd.github+json"
}


# Start looping on TyIns and get their ID and title.

for inftype in tqdm(tyin.keys()):
    local = tyin[inftype]
    itLabel = local[rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')][0].value
    itid = str(inftype).split('/')[-1]
    
    title = f"{itid} {itLabel}"
    print(f"{title} en cours")
    
    # Initiate the body of the issue.
    sortie = "### Résumé\n\n**Scope note**\n\n"
    
    # Defining string values for descriptive items.
    scopeNote = local[rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment')][0].value
    lien = str(inftype)
    
    sortie += f"{scopeNote}\n\n**Lien**\n\n[{str(inftype)}]({str(inftype)})\n\n"
    sortie += "### Alignement\n\n**Alignement proposé** :\n\n#### Alignement des rôles\n\n| Rôle (tel qu'apparaissant dans OntoME) | Range | Alignement | Notes |\n| ----- | ----- | ----- | ----- |"

    # Making the role table.
    
    for role in local['to_table'].keys():
        rolepreds = local['to_table'][role]
        roleID = str(role).split('/')[-1]
        
        notation = rolepreds[rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#notation')].value
        roleLabel = rolepreds[rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label')].value
        roleRange = str(rolepreds[rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range')])
        shortrange = roleRange.split('/')[-1]
        sortie += f"\n| [sym:{roleID} {roleLabel}]({str(role)}) | [sym:{shortrange}]({roleRange}) |   |   |"
        
    sortie += "\n\n### Commentaires"
    
    # Output a json archive of the data transmitted.
    with open(f"data/{itid}.json", "w") as openfile:
        json.dump({
            "title" : title,
            "body" : sortie
        }, openfile)
        
    # Output a markdown file for checking and archiving purposes.
    with open(f"data/{itid}.md", "w") as openfile:
        openfile.write(sortie)
    
    # If the current TyIn has no issue, post it.
    
    if itid not in dont_post and itid not in posted:
        payload = json.dumps({"title" : title, "body" : sortie, "labels":["TyIn", "En cours"]})
        response = requests.request("POST", url, data=payload, headers=headers)

        if response.status_code == 202 or response.status_code == 201:
            print('Successfully created Issue {0:s}'.format(title))
        else:
            print('Could not create Issue {0:s}'.format(title))
            print('Response says : ', response.content)
            failed.append(itid)
            
        print(response)
        posted.append(itid)
        
        print(f"👍 {title} a été posté !")
        time.sleep(30) # seconds
    else:
        print(f"{title} existe déjà.")
# Out:
#   0%|          | 0/133 [00:00<?, ?it/s]
# TyIn1 Lettre en cours
# TyIn1 Lettre existe déjà.
# TyIn100 Opinion exprimée à l'égard d'un objet en cours
# TyIn100 Opinion exprimée à l'égard d'un objet existe déjà.
# TyIn102 Intervention manuscrite en cours
# Successfully created Issue TyIn102 Intervention manuscrite
# <Response [201]>
# 👍 TyIn102 Intervention manuscrite a été posté !
# TyIn103 Exemplaire en cours
# Successfully created Issue TyIn103 Exemplaire
# <Response [201]>
# 👍 TyIn103 Exemplaire a été posté !
# TyIn104 Présence en cours
# Successfully created Issue TyIn104 Présence
# <Response [201]>
# 👍 TyIn104 Présence a été posté !
# TyIn105 Absence en cours
# Successfully created Issue TyIn105 Absence
# <Response [201]>
# 👍 TyIn105 Absence a été posté !
# TyIn107 Représentation visuelle multiple en cours
# Successfully created Issue TyIn107 Représentation visuelle multiple
# <Response [201]>
# 👍 TyIn107 Représentation visuelle multiple a été posté !
# TyIn108 Collection en cours
# Successfully created Issue TyIn108 Collection
# <Response [201]>
# 👍 TyIn108 Collection a été posté !
# TyIn11 Obtenir une qualité en cours
# TyIn11 Obtenir une qualité existe déjà.
# TyIn110 Education en cours
# Successfully created Issue TyIn110 Education
# <Response [201]>
# 👍 TyIn110 Education a été posté !
# TyIn111 Dédicace en cours
# Successfully created Issue TyIn111 Dédicace
# <Response [201]>
# 👍 TyIn111 Dédicace a été posté !
# TyIn112 Maladie en cours
# Successfully created Issue TyIn112 Maladie
# <Response [201]>
# 👍 TyIn112 Maladie a été posté !
# TyIn114 Invitation en cours
# Successfully created Issue TyIn114 Invitation
# <Response [201]>
# 👍 TyIn114 Invitation a été posté !
# TyIn115 Don en cours
# Successfully created Issue TyIn115 Don
# <Response [201]>
# 👍 TyIn115 Don a été posté !
# TyIn116 Prière en cours
# Successfully created Issue TyIn116 Prière
# <Response [201]>
# 👍 TyIn116 Prière a été posté !
# TyIn117 Lecture en cours
# Successfully created Issue TyIn117 Lecture
# <Response [201]>
# 👍 TyIn117 Lecture a été posté !
# TyIn118 Préface en cours
# Successfully created Issue TyIn118 Préface
# <Response [201]>
# 👍 TyIn118 Préface a été posté !
# TyIn12 Être membre d'un acteur collectif en cours
# TyIn12 Être membre d'un acteur collectif existe déjà.
# TyIn121 Démission en cours
# Successfully created Issue TyIn121 Démission
# <Response [201]>
# 👍 TyIn121 Démission a été posté !
# TyIn122 Réintégration (dans des fonctions) en cours
# Successfully created Issue TyIn122 Réintégration (dans des fonctions)
# <Response [201]>
# 👍 TyIn122 Réintégration (dans des fonctions) a été posté !
# TyIn123 Traitement en cours
# Successfully created Issue TyIn123 Traitement
# <Response [201]>
# 👍 TyIn123 Traitement a été posté !
# TyIn124 Document officiel en cours
# Successfully created Issue TyIn124 Document officiel
# <Response [201]>
# 👍 TyIn124 Document officiel a été posté !
# TyIn125 Décision (administrative, judiciaire) en cours
# Successfully created Issue TyIn125 Décision (administrative, judiciaire)
# <Response [201]>
# 👍 TyIn125 Décision (administrative, judiciaire) a été posté !
# TyIn126 Caution financière en cours
# Successfully created Issue TyIn126 Caution financière
# <Response [201]>
# 👍 TyIn126 Caution financière a été posté !
# TyIn127 Amende en cours
# Successfully created Issue TyIn127 Amende
# <Response [201]>
# 👍 TyIn127 Amende a été posté !
# TyIn128 Procès en cours
# Successfully created Issue TyIn128 Procès
# <Response [201]>
# 👍 TyIn128 Procès a été posté !
# TyIn129 Requête en cours
# Successfully created Issue TyIn129 Requête
# <Response [201]>
# 👍 TyIn129 Requête a été posté !
# TyIn13 Union en cours
# TyIn13 Union existe déjà.
# TyIn130 Posséder une qualité en cours
# TyIn130 Posséder une qualité existe déjà.
# TyIn131 Document ou acte manuscrit en cours
# Successfully created Issue TyIn131 Document ou acte manuscrit
# <Response [201]>
# 👍 TyIn131 Document ou acte manuscrit a été posté !
# TyIn132 Adopter une doctrine en cours
# Successfully created Issue TyIn132 Adopter une doctrine
# <Response [201]>
# 👍 TyIn132 Adopter une doctrine a été posté !
# TyIn133 Rattachement de territoire en cours
# Successfully created Issue TyIn133 Rattachement de territoire
# <Response [201]>
# 👍 TyIn133 Rattachement de territoire a été posté !
# TyIn134 Mariage en cours
# Successfully created Issue TyIn134 Mariage
# <Response [201]>
# 👍 TyIn134 Mariage a été posté !
# TyIn136 Absorption de territoire en cours
# Successfully created Issue TyIn136 Absorption de territoire
# <Response [201]>
# 👍 TyIn136 Absorption de territoire a été posté !
# TyIn137 Entretien en cours
# Successfully created Issue TyIn137 Entretien
# <Response [201]>
# 👍 TyIn137 Entretien a été posté !
# TyIn138 Séjour en cours
# Successfully created Issue TyIn138 Séjour
# <Response [201]>
# 👍 TyIn138 Séjour a été posté !
# TyIn139 Intervention en cours
# Successfully created Issue TyIn139 Intervention
# <Response [201]>
# 👍 TyIn139 Intervention a été posté !
# TyIn14 Naissance en cours
# Successfully created Issue TyIn14 Naissance
# <Response [201]>
# 👍 TyIn14 Naissance a été posté !
# TyIn140 Localisation relative d'un lieu en cours
# Successfully created Issue TyIn140 Localisation relative d'un lieu
# <Response [201]>
# 👍 TyIn140 Localisation relative d'un lieu a été posté !
# TyIn141 Existence d'une forme concrète en cours
# Successfully created Issue TyIn141 Existence d'une forme concrète
# <Response [201]>
# 👍 TyIn141 Existence d'une forme concrète a été posté !
# TyIn142 Texte (manuscrit ou imprimé) en cours
# Successfully created Issue TyIn142 Texte (manuscrit ou imprimé)
# <Response [201]>
# 👍 TyIn142 Texte (manuscrit ou imprimé) a été posté !
# TyIn143 Approbation pour impression en cours
# Successfully created Issue TyIn143 Approbation pour impression
# <Response [201]>
# 👍 TyIn143 Approbation pour impression a été posté !
# TyIn144 Demande en cours
# Successfully created Issue TyIn144 Demande
# <Response [201]>
# 👍 TyIn144 Demande a été posté !
# TyIn145 Passage d'un examen en cours
# Successfully created Issue TyIn145 Passage d'un examen
# <Response [201]>
# 👍 TyIn145 Passage d'un examen a été posté !
# TyIn146 Convocation en cours
# Successfully created Issue TyIn146 Convocation
# <Response [201]>
# 👍 TyIn146 Convocation a été posté !
# TyIn147 Acte de signer en cours
# Successfully created Issue TyIn147 Acte de signer
# <Response [201]>
# 👍 TyIn147 Acte de signer a été posté !
# TyIn148 Caractéristiques d'un objet en cours
# Successfully created Issue TyIn148 Caractéristiques d'un objet
# <Response [201]>
# 👍 TyIn148 Caractéristiques d'un objet a été posté !
# TyIn149 Suspension d'activité en cours
# Successfully created Issue TyIn149 Suspension d'activité
# <Response [201]>
# 👍 TyIn149 Suspension d'activité a été posté !
# TyIn15 Baptême en cours
# Successfully created Issue TyIn15 Baptême
# <Response [201]>
# 👍 TyIn15 Baptême a été posté !
# TyIn150 Sacre en cours
# Successfully created Issue TyIn150 Sacre
# <Response [201]>
# 👍 TyIn150 Sacre a été posté !
# TyIn151 Rite funéraire en cours
# Successfully created Issue TyIn151 Rite funéraire
# <Response [201]>
# 👍 TyIn151 Rite funéraire a été posté !
# TyIn152 Inspection en cours
# Successfully created Issue TyIn152 Inspection
# <Response [201]>
# 👍 TyIn152 Inspection a été posté !
# TyIn153 Activité d'un acteur collectif en cours
# Successfully created Issue TyIn153 Activité d'un acteur collectif
# <Response [201]>
# 👍 TyIn153 Activité d'un acteur collectif a été posté !
# TyIn154 Capacité à conférer une qualité en cours
# Successfully created Issue TyIn154 Capacité à conférer une qualité
# <Response [201]>
# 👍 TyIn154 Capacité à conférer une qualité a été posté !
# TyIn155 Création d'un personnage symbolique en cours
# Successfully created Issue TyIn155 Création d'un personnage symbolique
# <Response [201]>
# 👍 TyIn155 Création d'un personnage symbolique a été posté !
# TyIn156 Dévotion en cours
# Successfully created Issue TyIn156 Dévotion
# <Response [201]>
# 👍 TyIn156 Dévotion a été posté !
# TyIn157 Application d'une réforme régulière en cours
# Successfully created Issue TyIn157 Application d'une réforme régulière
# <Response [201]>
# 👍 TyIn157 Application d'une réforme régulière a été posté !
# TyIn158 Réponse en cours
# Successfully created Issue TyIn158 Réponse
# <Response [201]>
# 👍 TyIn158 Réponse a été posté !
# TyIn160 Existence d'un objet en cours
# Successfully created Issue TyIn160 Existence d'un objet
# <Response [201]>
# 👍 TyIn160 Existence d'un objet a été posté !
# TyIn165 Relation entre acteurs collectifs en cours
# Successfully created Issue TyIn165 Relation entre acteurs collectifs
# <Response [201]>
# 👍 TyIn165 Relation entre acteurs collectifs a été posté !
# TyIn166 Activité d'enseignement d'un acteur collectif en cours
# Successfully created Issue TyIn166 Activité d'enseignement d'un acteur collectif
# <Response [201]>
# 👍 TyIn166 Activité d'enseignement d'un acteur collectif a été posté !
# TyIn168 Période d'activité d'une relation en cours
# Successfully created Issue TyIn168 Période d'activité d'une relation
# <Response [201]>
# 👍 TyIn168 Période d'activité d'une relation a été posté !
# TyIn169 Exercice de pouvoir sur un territoire en cours
# Successfully created Issue TyIn169 Exercice de pouvoir sur un territoire
# <Response [201]>
# 👍 TyIn169 Exercice de pouvoir sur un territoire a été posté !
# TyIn170 Destruction en cours
# Successfully created Issue TyIn170 Destruction
# <Response [201]>
# 👍 TyIn170 Destruction a été posté !
# TyIn2 Qualification doctrinale en cours
# TyIn2 Qualification doctrinale existe déjà.
# TyIn25 Échange en cours
# Successfully created Issue TyIn25 Échange
# <Response [201]>
# 👍 TyIn25 Échange a été posté !
# TyIn26 Décès en cours
# Successfully created Issue TyIn26 Décès
# <Response [201]>
# 👍 TyIn26 Décès a été posté !
# TyIn27 Œuvre en cours
# Successfully created Issue TyIn27 Œuvre
# <Response [201]>
# 👍 TyIn27 Œuvre a été posté !
# TyIn28 Possession en cours
# Successfully created Issue TyIn28 Possession
# <Response [201]>
# 👍 TyIn28 Possession a été posté !
# TyIn3 Ouvrage imprimé en cours
# TyIn3 Ouvrage imprimé existe déjà.
# TyIn30 Création d'un acteur collectif en cours
# Successfully created Issue TyIn30 Création d'un acteur collectif
# <Response [201]>
# 👍 TyIn30 Création d'un acteur collectif a été posté !
# TyIn31 Fusion en cours
# Successfully created Issue TyIn31 Fusion
# <Response [201]>
# 👍 TyIn31 Fusion a été posté !
# TyIn32 Absorption (Intégration) en cours
# Successfully created Issue TyIn32 Absorption (Intégration)
# <Response [201]>
# 👍 TyIn32 Absorption (Intégration) a été posté !
# TyIn33 Fin de l'existence d'un acteur collectif en cours
# Successfully created Issue TyIn33 Fin de l'existence d'un acteur collectif
# <Response [201]>
# 👍 TyIn33 Fin de l'existence d'un acteur collectif a été posté !
# TyIn34 Séance en cours
# Successfully created Issue TyIn34 Séance
# <Response [201]>
# 👍 TyIn34 Séance a été posté !
# TyIn36 Localisation en cours
# Successfully created Issue TyIn36 Localisation
# <Response [201]>
# 👍 TyIn36 Localisation a été posté !
# TyIn37 Rattachement à une institution en cours
# Successfully created Issue TyIn37 Rattachement à une institution
# <Response [201]>
# 👍 TyIn37 Rattachement à une institution a été posté !
# TyIn41 Statut en cours
# Successfully created Issue TyIn41 Statut
# <Response [201]>
# 👍 TyIn41 Statut a été posté !
# TyIn42 Ouvrage ou création manuscrite en cours
# Successfully created Issue TyIn42 Ouvrage ou création manuscrite
# <Response [201]>
# 👍 TyIn42 Ouvrage ou création manuscrite a été posté !
# TyIn44 Nombre en cours
# Successfully created Issue TyIn44 Nombre
# <Response [201]>
# 👍 TyIn44 Nombre a été posté !
# TyIn49 Construction en cours
# Successfully created Issue TyIn49 Construction
# <Response [201]>
# 👍 TyIn49 Construction a été posté !
# TyIn5 Traduction en cours
# Successfully created Issue TyIn5 Traduction
# <Response [201]>
# 👍 TyIn5 Traduction a été posté !
# TyIn51 Recette en cours
# Successfully created Issue TyIn51 Recette
# <Response [201]>
# 👍 TyIn51 Recette a été posté !
# TyIn52 Pension ecclésiastique en cours
# Successfully created Issue TyIn52 Pension ecclésiastique
# <Response [201]>
# 👍 TyIn52 Pension ecclésiastique a été posté !
# TyIn53 Information biographique en cours
# Successfully created Issue TyIn53 Information biographique
# <Response [201]>
# 👍 TyIn53 Information biographique a été posté !
# TyIn54 Analyse de contenu en cours
# Successfully created Issue TyIn54 Analyse de contenu
# <Response [201]>
# 👍 TyIn54 Analyse de contenu a été posté !
# TyIn55 Relation entre personnes en cours
# TyIn55 Relation entre personnes existe déjà.
# TyIn56 Autographe en cours
# Successfully created Issue TyIn56 Autographe
# <Response [201]>
# 👍 TyIn56 Autographe a été posté !
# TyIn57 Signature autographe en cours
# Successfully created Issue TyIn57 Signature autographe
# <Response [201]>
# 👍 TyIn57 Signature autographe a été posté !
# TyIn58 Célébration religieuse chrétienne en cours
# Successfully created Issue TyIn58 Célébration religieuse chrétienne
# <Response [201]>
# 👍 TyIn58 Célébration religieuse chrétienne a été posté !
# TyIn59 Quittance en cours
# Successfully created Issue TyIn59 Quittance
# <Response [201]>
# 👍 TyIn59 Quittance a été posté !
# TyIn6 Nomination en cours
# TyIn6 Nomination existe déjà.
# TyIn60 Demande de funérailles en cours
# Successfully created Issue TyIn60 Demande de funérailles
# <Response [201]>
# 👍 TyIn60 Demande de funérailles a été posté !
# TyIn61 Vente en cours
# Successfully created Issue TyIn61 Vente
# <Response [201]>
# 👍 TyIn61 Vente a été posté !
# TyIn62 Passage d'un acte notarié en cours
# Successfully created Issue TyIn62 Passage d'un acte notarié
# <Response [201]>
# 👍 TyIn62 Passage d'un acte notarié a été posté !
# TyIn63 Testament en cours
# Successfully created Issue TyIn63 Testament
# <Response [201]>
# 👍 TyIn63 Testament a été posté !
# TyIn64 Legs en cours
# Successfully created Issue TyIn64 Legs
# <Response [201]>
# 👍 TyIn64 Legs a été posté !
# TyIn66 Événement en cours
# Successfully created Issue TyIn66 Événement
# <Response [201]>
# 👍 TyIn66 Événement a été posté !
# TyIn67 Permis de lecture en cours
# Successfully created Issue TyIn67 Permis de lecture
# <Response [201]>
# 👍 TyIn67 Permis de lecture a été posté !
# TyIn68 Représentation visuelle unique en cours
# Successfully created Issue TyIn68 Représentation visuelle unique
# <Response [201]>
# 👍 TyIn68 Représentation visuelle unique a été posté !
# TyIn69 Constitution de rente en cours
# Successfully created Issue TyIn69 Constitution de rente
# <Response [201]>
# 👍 TyIn69 Constitution de rente a été posté !
# TyIn7 Exercice de la fonction en cours
# TyIn7 Exercice de la fonction existe déjà.
# TyIn70 Procuration en cours
# Successfully created Issue TyIn70 Procuration
# <Response [201]>
# 👍 TyIn70 Procuration a été posté !
# TyIn71 Location en cours
# Successfully created Issue TyIn71 Location
# <Response [201]>
# 👍 TyIn71 Location a été posté !
# TyIn72 Obligation en cours
# Successfully created Issue TyIn72 Obligation
# <Response [201]>
# 👍 TyIn72 Obligation a été posté !
# TyIn73 Métayage en cours
# Successfully created Issue TyIn73 Métayage
# <Response [201]>
# 👍 TyIn73 Métayage a été posté !
# TyIn74 Licenciement en cours
# Successfully created Issue TyIn74 Licenciement
# <Response [201]>
# 👍 TyIn74 Licenciement a été posté !
# TyIn75 Embauche en cours
# Successfully created Issue TyIn75 Embauche
# <Response [201]>
# 👍 TyIn75 Embauche a été posté !
# TyIn76 Vêture en cours
# Successfully created Issue TyIn76 Vêture
# <Response [201]>
# 👍 TyIn76 Vêture a été posté !
# TyIn77 Affectation militaire en cours
# Successfully created Issue TyIn77 Affectation militaire
# <Response [201]>
# 👍 TyIn77 Affectation militaire a été posté !
# TyIn78 Caractère physique en cours
# Successfully created Issue TyIn78 Caractère physique
# <Response [201]>
# 👍 TyIn78 Caractère physique a été posté !
# TyIn79 Formulation d'un avis en cours
# Successfully created Issue TyIn79 Formulation d'un avis
# <Response [201]>
# 👍 TyIn79 Formulation d'un avis a été posté !
# TyIn8 Election en cours
# Successfully created Issue TyIn8 Election
# <Response [201]>
# 👍 TyIn8 Election a été posté !
# TyIn80 Candidature en cours
# Successfully created Issue TyIn80 Candidature
# <Response [201]>
# 👍 TyIn80 Candidature a été posté !
# TyIn81 Inscription dans un registre en cours
# Successfully created Issue TyIn81 Inscription dans un registre
# <Response [201]>
# 👍 TyIn81 Inscription dans un registre a été posté !
# TyIn82 Profession religieuse en cours
# Successfully created Issue TyIn82 Profession religieuse
# <Response [201]>
# 👍 TyIn82 Profession religieuse a été posté !
# TyIn83 Affectation (à emploi, un service, un usage) en cours
# Successfully created Issue TyIn83 Affectation (à emploi, un service, un usage)
# <Response [201]>
# 👍 TyIn83 Affectation (à emploi, un service, un usage) a été posté !
# TyIn84 Abandon de scolarité en cours
# Successfully created Issue TyIn84 Abandon de scolarité
# <Response [201]>
# 👍 TyIn84 Abandon de scolarité a été posté !
# TyIn85 Moyenne (obtention d'une) en cours
# Successfully created Issue TyIn85 Moyenne (obtention d'une)
# <Response [201]>
# 👍 TyIn85 Moyenne (obtention d'une) a été posté !
# TyIn86 Nationalité politique en cours
# Successfully created Issue TyIn86 Nationalité politique
# <Response [201]>
# 👍 TyIn86 Nationalité politique a été posté !
# TyIn87 Réception mondaine en cours
# Successfully created Issue TyIn87 Réception mondaine
# <Response [201]>
# 👍 TyIn87 Réception mondaine a été posté !
# TyIn88 Service militaire actif en cours
# Successfully created Issue TyIn88 Service militaire actif
# <Response [201]>
# 👍 TyIn88 Service militaire actif a été posté !
# TyIn89 Fermage en cours
# Successfully created Issue TyIn89 Fermage
# <Response [201]>
# 👍 TyIn89 Fermage a été posté !
# TyIn90 Transfert d'un(e) religieux(se) en cours
# Successfully created Issue TyIn90 Transfert d'un(e) religieux(se)
# <Response [201]>
# 👍 TyIn90 Transfert d'un(e) religieux(se) a été posté !
# TyIn91 Assemblée en cours
# Successfully created Issue TyIn91 Assemblée
# <Response [201]>
# 👍 TyIn91 Assemblée a été posté !
# TyIn92 Attribution de l'organisation en cours
# Successfully created Issue TyIn92 Attribution de l'organisation
# <Response [201]>
# 👍 TyIn92 Attribution de l'organisation a été posté !
# TyIn93 Attribution de crédit en cours
# Successfully created Issue TyIn93 Attribution de crédit
# <Response [201]>
# 👍 TyIn93 Attribution de crédit a été posté !
# TyIn94 Versement (Dépense) en cours
# Successfully created Issue TyIn94 Versement (Dépense)
# <Response [201]>
# 👍 TyIn94 Versement (Dépense) a été posté !
# TyIn95 Représentation en cours
# Successfully created Issue TyIn95 Représentation
# <Response [201]>
# 👍 TyIn95 Représentation a été posté !
# TyIn96 Edition d'un périodique en cours
# Successfully created Issue TyIn96 Edition d'un périodique
# <Response [201]>
# 👍 TyIn96 Edition d'un périodique a été posté !
# TyIn97 Enseignement en cours
# Successfully created Issue TyIn97 Enseignement
# <Response [201]>
# 👍 TyIn97 Enseignement a été posté !
# TyIn98 Suivre une formation en cours
# Successfully created Issue TyIn98 Suivre une formation
# <Response [201]>
# 👍 TyIn98 Suivre une formation a été posté !
# TyIn99 Relation de pouvoir entre acteurs collectifs en cours
# Successfully created Issue TyIn99 Relation de pouvoir entre acteurs collectifs
# <Response [201]>
# 👍 TyIn99 Relation de pouvoir entre acteurs collectifs a été posté !

# %% [markdown]
# ## Check on job execution

# %%
print("Les issues suivantes ont été postées :")
for issue in posted:
    print(f"\t\t{issue}")
    
print("\n\nLes issues suivantes ont échoué :")
for issue in failed:
    print(f"\n\n{issue}")
# Out:
# Les issues suivantes ont été postées :
# 		TyIn100
# 		TyIn102
# 		TyIn103
# 		TyIn104
# 		TyIn105
# 		TyIn107
# 		TyIn108
# 		TyIn110
# 		TyIn111
# 		TyIn112
# 		TyIn114
# 		TyIn115
# 		TyIn116
# 		TyIn117
# 		TyIn118
# 		TyIn121
# 		TyIn122
# 		TyIn123
# 		TyIn124
# 		TyIn125
# 		TyIn126
# 		TyIn127
# 		TyIn128
# 		TyIn129
# 		TyIn131
# 		TyIn132
# 		TyIn133
# 		TyIn134
# 		TyIn136
# 		TyIn137
# 		TyIn138
# 		TyIn139
# 		TyIn14
# 		TyIn140
# 		TyIn141
# 		TyIn142
# 		TyIn143
# 		TyIn144
# 		TyIn145
# 		TyIn146
# 		TyIn147
# 		TyIn148
# 		TyIn149
# 		TyIn15
# 		TyIn150
# 		TyIn151
# 		TyIn152
# 		TyIn153
# 		TyIn154
# 		TyIn155
# 		TyIn156
# 		TyIn157
# 		TyIn158
# 		TyIn160
# 		TyIn165
# 		TyIn166
# 		TyIn168
# 		TyIn169
# 		TyIn170
# 		TyIn25
# 		TyIn26
# 		TyIn27
# 		TyIn28
# 		TyIn30
# 		TyIn31
# 		TyIn32
# 		TyIn33
# 		TyIn34
# 		TyIn36
# 		TyIn37
# 		TyIn41
# 		TyIn42
# 		TyIn44
# 		TyIn49
# 		TyIn5
# 		TyIn51
# 		TyIn52
# 		TyIn53
# 		TyIn54
# 		TyIn56
# 		TyIn57
# 		TyIn58
# 		TyIn59
# 		TyIn60
# 		TyIn61
# 		TyIn62
# 		TyIn63
# 		TyIn64
# 		TyIn66
# 		TyIn67
# 		TyIn68
# 		TyIn69
# 		TyIn70
# 		TyIn71
# 		TyIn72
# 		TyIn73
# 		TyIn74
# 		TyIn75
# 		TyIn76
# 		TyIn77
# 		TyIn78
# 		TyIn79
# 		TyIn8
# 		TyIn80
# 		TyIn81
# 		TyIn82
# 		TyIn83
# 		TyIn84
# 		TyIn85
# 		TyIn86
# 		TyIn87
# 		TyIn88
# 		TyIn89
# 		TyIn90
# 		TyIn91
# 		TyIn92
# 		TyIn93
# 		TyIn94
# 		TyIn95
# 		TyIn96
# 		TyIn97
# 		TyIn98
# 		TyIn99
#
#
# Les issues suivantes ont échoué :

# %% [markdown]
# (Empty = no issue failed.)
#
# ## Documentation used:
#
# -----
#
# https://medium.com/analytics-vidhya/getting-started-with-github-api-dc7057e2834d
#
# https://docs.github.com/fr/rest/issues/issues?apiVersion=2022-11-28#create-an-issue
#
# ------
#
# https://medium.datadriveninvestor.com/github-issue-via-python-171c7fee0629
#
# https://docs.github.com/fr/rest/guides/best-practices-for-integrators?apiVersion=2022-11-28#dealing-with-secondary-rate-limits
#
# https://docs.github.com/fr/rest/overview/resources-in-the-rest-api?apiVersion=2022-11-28#rate-limiting
#
# https://docs.github.com/fr/actions/security-guides/automatic-token-authentication
