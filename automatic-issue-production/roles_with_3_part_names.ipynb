# %% [markdown]
# # Préparer des copiers-collers manuels
#
# Ce script permet de réparer manuellement un oubli dans le [script de création d'issues](production_issues.ipynb). Il s'agit uniquement d'une préparation des données qui ont ensuite été copiées-collées manuellement dans les issues concernées.
#
# ## Récupérer les données à transformer en markdown
#
# Le contenu de cette variable est issu d'expressions régulières exécutées directement* sur le XML/RDFS de Symogih dans le dossier `./sources`.
#
# Recherche :
# ```regex
# <owl:ObjectProperty rdf:about="https://ontome.net/ns/symogih/([^_">]+_[^_">]+_[^_">]+)">[^<]+<rdfs:range rdf:resource="https://ontome.net/ns/symogih/([^"]+)"[^\n]+\n[^\n]+<rdfs:comment[^\n]+\n[^\n]+<rdfs:label xml:lang="fr">([^<]+)</rdfs:label>
# ```
#
# Remplacement :
# ```regex
# {'full':'| \[\1 \3\]\(https://ontome.net/ns/symogih/\1\) | \[\sym:2\]\(https://ontome.net/ns/symogih/\2\) |  |  |', 'TyIn':'\2'},
# ```
#
# Les résultats de remplacement ont ensuite été rassemblés et copiés ci-dessous.

# %%
contents = [{'full':'| [TyRo138_TyIn138_2 occasionner](https://ontome.net/ns/symogih/TyRo138_TyIn138_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn138'},
{'full':'| [TyRo176_TyIn12_1 occasionner la fin](https://ontome.net/ns/symogih/TyRo176_TyIn12_1) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn12'},
{'full':'| [TyRo126_TyIn125_1 être chargé de](https://ontome.net/ns/symogih/TyRo126_TyIn125_1) | [sym:Actor](https://ontome.net/ns/symogih/Actor) |  |  |', 'TyIn':'TyIn125'},
{'full':'| [TyRo72_TyIn125_1 justifier](https://ontome.net/ns/symogih/TyRo72_TyIn125_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn125'},
{'full':'| [TyRo176_TyIn149_1 occasionner la fin](https://ontome.net/ns/symogih/TyRo176_TyIn149_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn149'},
{'full':'| [TyRo72_TyIn149_1 justifier](https://ontome.net/ns/symogih/TyRo72_TyIn149_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn149'},
{'full':'| [TyRo138_TyIn149_1 occasionner](https://ontome.net/ns/symogih/TyRo138_TyIn149_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn149'},
{'full':'| [TyRo174_TyIn30_1 être le contexte](https://ontome.net/ns/symogih/TyRo174_TyIn30_1) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn30'},
{'full':'| [TyRo110_TyIn79_1 exprimer](https://ontome.net/ns/symogih/TyRo110_TyIn79_1) | [sym:Actor](https://ontome.net/ns/symogih/Actor) |  |  |', 'TyIn':'TyIn79'},
{'full':'| [TyRo176_TyIn7_1 occasionner la fin](https://ontome.net/ns/symogih/TyRo176_TyIn7_1) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn7'},
{'full':'| [TyRo16_TyIn7_1 être l\'origine](https://ontome.net/ns/symogih/TyRo16_TyIn7_1) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn7'},
{'full':'| [TyRo21_TyIn85_1 être concerné](https://ontome.net/ns/symogih/TyRo21_TyIn85_1) | [sym:TyIn98](https://ontome.net/ns/symogih/TyIn98) |  |  |', 'TyIn':'TyIn85'},
{'full':'| [TyRo133_TyIn98_1 fréquenter](https://ontome.net/ns/symogih/TyRo133_TyIn98_1) | [sym:Actor](https://ontome.net/ns/symogih/Actor) |  |  |', 'TyIn':'TyIn98'},
{'full':'| [TyRo13_TyIn102_1 être l\'objet](https://ontome.net/ns/symogih/TyRo13_TyIn102_1) | [sym:InMaOb](https://ontome.net/ns/symogih/InMaOb) |  |  |', 'TyIn':'TyIn102'},
{'full':'| [TyRo21_TyIn103_1 être concerné](https://ontome.net/ns/symogih/TyRo21_TyIn103_1) | [sym:Bibl](https://ontome.net/ns/symogih/Bibl) |  |  |', 'TyIn':'TyIn103'},
{'full':'| [TyRo72_TyIn104_1 justifier](https://ontome.net/ns/symogih/TyRo72_TyIn104_1) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn104'},
{'full':'| [TyRo72_TyIn105_1 justifier](https://ontome.net/ns/symogih/TyRo72_TyIn105_1) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn105'},
{'full':'| [TyRo16_TyIn107_1 être l\'origine](https://ontome.net/ns/symogih/TyRo16_TyIn107_1) | [sym:TyIn68](https://ontome.net/ns/symogih/TyIn68) |  |  |', 'TyIn':'TyIn107'},
{'full':'| [TyRo181_TyIn128_1 aboutir](https://ontome.net/ns/symogih/TyRo181_TyIn128_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn128'},
{'full':'| [TyRo138_TyIn128_1 occasionner](https://ontome.net/ns/symogih/TyRo138_TyIn128_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn128'},
{'full':'| [TyRo72_TyIn128_1 justifier](https://ontome.net/ns/symogih/TyRo72_TyIn128_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn128'},
{'full':'| [TyRo2_TyIn108_1 appartenir](https://ontome.net/ns/symogih/TyRo2_TyIn108_1) | [sym:MaOb](https://ontome.net/ns/symogih/MaOb) |  |  |', 'TyIn':'TyIn108'},
{'full':'| [TyRo161_TyIn124_1 être publié](https://ontome.net/ns/symogih/TyRo161_TyIn124_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn124'},
{'full':'| [TyRo3_TyIn131_1 être une création](https://ontome.net/ns/symogih/TyRo3_TyIn131_1) | [sym:InMaOb](https://ontome.net/ns/symogih/InMaOb) |  |  |', 'TyIn':'TyIn131'},
{'full':'| [TyRo138_TyIn138_1 occasionner](https://ontome.net/ns/symogih/TyRo138_TyIn138_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn138'},
{'full':'| [TyRo176_TyIn138_1 occasionner la fin](https://ontome.net/ns/symogih/TyRo176_TyIn138_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn138'},
{'full':'| [TyRo176_TyIn13_1 occasionner la fin](https://ontome.net/ns/symogih/TyRo176_TyIn13_1) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn13'},
{'full':'| [TyRo138_TyIn13_1 occasionner](https://ontome.net/ns/symogih/TyRo138_TyIn13_1) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn13'},
{'full':'| [TyRo9_TyIn144_1 être la destination](https://ontome.net/ns/symogih/TyRo9_TyIn144_1) | [sym:Actor](https://ontome.net/ns/symogih/Actor) |  |  |', 'TyIn':'TyIn144'},
{'full':'| [TyRo72_TyIn144_1 justifier](https://ontome.net/ns/symogih/TyRo72_TyIn144_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn144'},
{'full':'| [TyRo174_TyIn144_1 être le contexte](https://ontome.net/ns/symogih/TyRo174_TyIn144_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn144'},
{'full':'| [TyRo190_TyIn147_1 être signé](https://ontome.net/ns/symogih/TyRo190_TyIn147_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn147'},
{'full':'| [TyRo72_TyIn150_1 justifier](https://ontome.net/ns/symogih/TyRo72_TyIn150_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn150'},
{'full':'| [TyRo72_TyIn152_1 justifier](https://ontome.net/ns/symogih/TyRo72_TyIn152_1) | [sym:InAbOb](https://ontome.net/ns/symogih/InAbOb) |  |  |', 'TyIn':'TyIn152'},
{'full':'| [TyRo13_TyIn156_1 être l\'objet](https://ontome.net/ns/symogih/TyRo13_TyIn156_1) | [sym:MaOb](https://ontome.net/ns/symogih/MaOb) |  |  |', 'TyIn':'TyIn156'},
{'full':'| [TyRo8_TyIn156_1 localiser](https://ontome.net/ns/symogih/TyRo8_TyIn156_1) | [sym:LoOb](https://ontome.net/ns/symogih/LoOb) |  |  |', 'TyIn':'TyIn156'},
{'full':'| [TyRo9_TyIn158_1 être la destination](https://ontome.net/ns/symogih/TyRo9_TyIn158_1) | [sym:Actor](https://ontome.net/ns/symogih/Actor) |  |  |', 'TyIn':'TyIn158'},
{'full':'| [TyRo174_TyIn158_1 être le contexte](https://ontome.net/ns/symogih/TyRo174_TyIn158_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn158'},
{'full':'| [TyRo148_TyIn158_1 être le support](https://ontome.net/ns/symogih/TyRo148_TyIn158_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn158'},
{'full':'| [TyRo16_TyIn26_1 être l\'origine](https://ontome.net/ns/symogih/TyRo16_TyIn26_1) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn26'},
{'full':'| [TyRo2_TyIn27_1 appartenir](https://ontome.net/ns/symogih/TyRo2_TyIn27_1) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn27'},
{'full':'| [TyRo21_TyIn84_1 être concerné](https://ontome.net/ns/symogih/TyRo21_TyIn84_1) | [sym:StrCoAc](https://ontome.net/ns/symogih/StrCoAc) |  |  |', 'TyIn':'TyIn84'},
{'full':'| [TyRo3_TyIn3_1 être une création](https://ontome.net/ns/symogih/TyRo3_TyIn3_1) | [sym:Bibl](https://ontome.net/ns/symogih/Bibl) |  |  |', 'TyIn':'TyIn3'},
{'full':'| [TyRo72_TyIn51_1 justifier](https://ontome.net/ns/symogih/TyRo72_TyIn51_1) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn51'},
{'full':'| [TyRo174_TyIn55_1 être le contexte](https://ontome.net/ns/symogih/TyRo174_TyIn55_1) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn55'},
{'full':'| [TyRo72_TyIn59_1 justifier](https://ontome.net/ns/symogih/TyRo72_TyIn59_1) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn59'},
{'full':'| [TyRo174_TyIn66_1 être le contexte](https://ontome.net/ns/symogih/TyRo174_TyIn66_1) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn66'},
{'full':'| [TyRo21_TyIn6_1 être concerné](https://ontome.net/ns/symogih/TyRo21_TyIn6_1) | [sym:Actor](https://ontome.net/ns/symogih/Actor) |  |  |', 'TyIn':'TyIn6'},
{'full':'| [TyRo125_TyIn86_1 attribuer](https://ontome.net/ns/symogih/TyRo125_TyIn86_1) | [sym:Terr](https://ontome.net/ns/symogih/Terr) |  |  |', 'TyIn':'TyIn86'},
{'full':'| [TyRo16_TyIn90_2 être l\'origine](https://ontome.net/ns/symogih/TyRo16_TyIn90_2) | [sym:NaPl](https://ontome.net/ns/symogih/NaPl) |  |  |', 'TyIn':'TyIn90'},
{'full':'| [TyRo148_TyIn158_2 être le support](https://ontome.net/ns/symogih/TyRo148_TyIn158_2) | [sym:MaOb](https://ontome.net/ns/symogih/MaOb) |  |  |', 'TyIn':'TyIn158'},
{'full':'| [TyRo9_TyIn90_1 être la destination](https://ontome.net/ns/symogih/TyRo9_TyIn90_1) | [sym:StrCoAc](https://ontome.net/ns/symogih/StrCoAc) |  |  |', 'TyIn':'TyIn90'},
{'full':'| [TyRo16_TyIn90_1 être l\'origine](https://ontome.net/ns/symogih/TyRo16_TyIn90_1) | [sym:StrCoAc](https://ontome.net/ns/symogih/StrCoAc) |  |  |', 'TyIn':'TyIn90'},
{'full':'| [TyRo12_TyIn166_1 exercer](https://ontome.net/ns/symogih/TyRo12_TyIn166_1) | [sym:Group](https://ontome.net/ns/symogih/Group) |  |  |', 'TyIn':'TyIn166'},
{'full':'| [TyRo72_TyIn166_1 justifier](https://ontome.net/ns/symogih/TyRo72_TyIn166_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn166'},
{'full':'| [TyRo176_TyIn166_1 occasionner la fin](https://ontome.net/ns/symogih/TyRo176_TyIn166_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn166'},
{'full':'| [TyRo12_TyIn166_2 exercer](https://ontome.net/ns/symogih/TyRo12_TyIn166_2) | [sym:GenSoCh](https://ontome.net/ns/symogih/GenSoCh) |  |  |', 'TyIn':'TyIn166'},
{'full':'| [TyRo72_TyIn166_2 justifier](https://ontome.net/ns/symogih/TyRo72_TyIn166_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn166'},
{'full':'| [TyRo176_TyIn166_2 occasionner la fin](https://ontome.net/ns/symogih/TyRo176_TyIn166_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn166'},
{'full':'| [TyRo138_TyIn169_1 occasionner](https://ontome.net/ns/symogih/TyRo138_TyIn169_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn169'},
{'full':'| [TyRo138_TyIn169_2 occasionner](https://ontome.net/ns/symogih/TyRo138_TyIn169_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn169'},
{'full':'| [TyRo176_TyIn169_1 occasionner la fin](https://ontome.net/ns/symogih/TyRo176_TyIn169_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn169'},
{'full':'| [TyRo176_TyIn169_2 occasionner la fin](https://ontome.net/ns/symogih/TyRo176_TyIn169_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn169'},
{'full':'| [TyRo138_TyIn168_2 occasionner](https://ontome.net/ns/symogih/TyRo138_TyIn168_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn168'},
{'full':'| [TyRo176_TyIn168_1 occasionner la fin](https://ontome.net/ns/symogih/TyRo176_TyIn168_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn168'},
{'full':'| [TyRo176_TyIn168_2 occasionner la fin](https://ontome.net/ns/symogih/TyRo176_TyIn168_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn168'},
{'full':'| [TyRo138_TyIn165_1 occasionner](https://ontome.net/ns/symogih/TyRo138_TyIn165_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn165'},
{'full':'| [TyRo138_TyIn165_2 occasionner](https://ontome.net/ns/symogih/TyRo138_TyIn165_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn165'},
{'full':'| [TyRo176_TyIn165_1 occasionner la fin](https://ontome.net/ns/symogih/TyRo176_TyIn165_1) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn165'},
{'full':'| [TyRo176_TyIn165_2 occasionner la fin](https://ontome.net/ns/symogih/TyRo176_TyIn165_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn165'},
{'full':'| [TyRo174_TyIn158_2 être le contexte](https://ontome.net/ns/symogih/TyRo174_TyIn158_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn158'},
{'full':'| [TyRo9_TyIn158_2 être la destination](https://ontome.net/ns/symogih/TyRo9_TyIn158_2) | [sym:LoOb](https://ontome.net/ns/symogih/LoOb) |  |  |', 'TyIn':'TyIn158'},
{'full':'| [TyRo8_TyIn156_2 localiser](https://ontome.net/ns/symogih/TyRo8_TyIn156_2) | [sym:GenAbOb](https://ontome.net/ns/symogih/GenAbOb) |  |  |', 'TyIn':'TyIn156'},
{'full':'| [TyRo13_TyIn156_2 être l\'objet](https://ontome.net/ns/symogih/TyRo13_TyIn156_2) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn156'},
{'full':'| [TyRo72_TyIn152_2 justifier](https://ontome.net/ns/symogih/TyRo72_TyIn152_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn152'},
{'full':'| [TyRo72_TyIn150_2 justifier](https://ontome.net/ns/symogih/TyRo72_TyIn150_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn150'},
{'full':'| [TyRo138_TyIn149_2 occasionner](https://ontome.net/ns/symogih/TyRo138_TyIn149_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn149'},
{'full':'| [TyRo176_TyIn149_2 occasionner la fin](https://ontome.net/ns/symogih/TyRo176_TyIn149_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn149'},
{'full':'| [TyRo72_TyIn149_2 justifier](https://ontome.net/ns/symogih/TyRo72_TyIn149_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn149'},
{'full':'| [TyRo190_TyIn147_2 être signé](https://ontome.net/ns/symogih/TyRo190_TyIn147_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn147'},
{'full':'| [TyRo72_TyIn144_2 justifier](https://ontome.net/ns/symogih/TyRo72_TyIn144_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn144'},
{'full':'| [TyRo174_TyIn144_2 être le contexte](https://ontome.net/ns/symogih/TyRo174_TyIn144_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn144'},
{'full':'| [TyRo9_TyIn144_2 être la destination](https://ontome.net/ns/symogih/TyRo9_TyIn144_2) | [sym:GenSoCh](https://ontome.net/ns/symogih/GenSoCh) |  |  |', 'TyIn':'TyIn144'},
{'full':'| [TyRo176_TyIn138_2 occasionner la fin](https://ontome.net/ns/symogih/TyRo176_TyIn138_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn138'},
{'full':'| [TyRo3_TyIn131_2 être une création](https://ontome.net/ns/symogih/TyRo3_TyIn131_2) | [sym:DoUn](https://ontome.net/ns/symogih/DoUn) |  |  |', 'TyIn':'TyIn131'},
{'full':'| [TyRo138_TyIn128_2 occasionner](https://ontome.net/ns/symogih/TyRo138_TyIn128_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn128'},
{'full':'| [TyRo181_TyIn128_2 aboutir](https://ontome.net/ns/symogih/TyRo181_TyIn128_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn128'},
{'full':'| [TyRo72_TyIn128_2 justifier](https://ontome.net/ns/symogih/TyRo72_TyIn128_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn128'},
{'full':'| [TyRo126_TyIn125_2 être chargé de](https://ontome.net/ns/symogih/TyRo126_TyIn125_2) | [sym:SoCh](https://ontome.net/ns/symogih/SoCh) |  |  |', 'TyIn':'TyIn125'},
{'full':'| [TyRo72_TyIn125_2 justifier](https://ontome.net/ns/symogih/TyRo72_TyIn125_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn125'},
{'full':'| [TyRo161_TyIn124_2 être publié](https://ontome.net/ns/symogih/TyRo161_TyIn124_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn124'},
{'full':'| [TyRo2_TyIn108_2 appartenir](https://ontome.net/ns/symogih/TyRo2_TyIn108_2) | [sym:TyIn108](https://ontome.net/ns/symogih/TyIn108) |  |  |', 'TyIn':'TyIn108'},
{'full':'| [TyRo16_TyIn107_2 être l\'origine](https://ontome.net/ns/symogih/TyRo16_TyIn107_2) | [sym:MaOb](https://ontome.net/ns/symogih/MaOb) |  |  |', 'TyIn':'TyIn107'},
{'full':'| [TyRo72_TyIn105_2 justifier](https://ontome.net/ns/symogih/TyRo72_TyIn105_2) | [sym:GenAbOb](https://ontome.net/ns/symogih/GenAbOb) |  |  |', 'TyIn':'TyIn105'},
{'full':'| [TyRo72_TyIn104_2 justifier](https://ontome.net/ns/symogih/TyRo72_TyIn104_2) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn104'},
{'full':'| [TyRo21_TyIn103_2 être concerné](https://ontome.net/ns/symogih/TyRo21_TyIn103_2) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn103'},
{'full':'| [TyRo13_TyIn102_2 être l\'objet](https://ontome.net/ns/symogih/TyRo13_TyIn102_2) | [sym:TyIn103](https://ontome.net/ns/symogih/TyIn103) |  |  |', 'TyIn':'TyIn102'},
{'full':'| [TyRo16_TyIn90_3 être l\'origine](https://ontome.net/ns/symogih/TyRo16_TyIn90_3) | [sym:Info](https://ontome.net/ns/symogih/Info) |  |  |', 'TyIn':'TyIn90'},
{'full':'| [TyRo9_TyIn90_2 être la destination](https://ontome.net/ns/symogih/TyRo9_TyIn90_2) | [sym:NaPl](https://ontome.net/ns/symogih/NaPl) |  |  |', 'TyIn':'TyIn90'},
{'full':'| [TyRo133_TyIn98_2 fréquenter](https://ontome.net/ns/symogih/TyRo133_TyIn98_2) | [sym:GenAbOb](https://ontome.net/ns/symogih/GenAbOb) |  |  |', 'TyIn':'TyIn98'},
{'full':'| [TyRo125_TyIn86_2 attribuer](https://ontome.net/ns/symogih/TyRo125_TyIn86_2) | [sym:StrCoAc](https://ontome.net/ns/symogih/StrCoAc) |  |  |', 'TyIn':'TyIn86'},
{'full':'| [TyRo21_TyIn85_2 être concerné](https://ontome.net/ns/symogih/TyRo21_TyIn85_2) | [sym:Group](https://ontome.net/ns/symogih/Group) |  |  |', 'TyIn':'TyIn85'},
{'full':'| [TyRo21_TyIn84_2 être concerné](https://ontome.net/ns/symogih/TyRo21_TyIn84_2) | [sym:GenAbOb](https://ontome.net/ns/symogih/GenAbOb) |  |  |', 'TyIn':'TyIn84'},
{'full':'| [TyRo110_TyIn79_2 exprimer](https://ontome.net/ns/symogih/TyRo110_TyIn79_2) | [sym:SoCh](https://ontome.net/ns/symogih/SoCh) |  |  |', 'TyIn':'TyIn79'},
{'full':'| [TyRo174_TyIn66_2 être le contexte](https://ontome.net/ns/symogih/TyRo174_TyIn66_2) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn66'},
{'full':'| [TyRo72_TyIn59_2 justifier](https://ontome.net/ns/symogih/TyRo72_TyIn59_2) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn59'},
{'full':'| [TyRo174_TyIn55_2 être le contexte](https://ontome.net/ns/symogih/TyRo174_TyIn55_2) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn55'},
{'full':'| [TyRo72_TyIn51_2 justifier](https://ontome.net/ns/symogih/TyRo72_TyIn51_2) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn51'},
{'full':'| [TyRo174_TyIn30_2 être le contexte](https://ontome.net/ns/symogih/TyRo174_TyIn30_2) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn30'},
{'full':'| [TyRo2_TyIn27_2 appartenir](https://ontome.net/ns/symogih/TyRo2_TyIn27_2) | [sym:Obj](https://ontome.net/ns/symogih/Obj) |  |  |', 'TyIn':'TyIn27'},
{'full':'| [TyRo16_TyIn26_2 être l\'origine](https://ontome.net/ns/symogih/TyRo16_TyIn26_2) | [sym:GenAbOb](https://ontome.net/ns/symogih/GenAbOb) |  |  |', 'TyIn':'TyIn26'},
{'full':'| [TyRo138_TyIn13_2 occasionner](https://ontome.net/ns/symogih/TyRo138_TyIn13_2) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn13'},
{'full':'| [TyRo176_TyIn13_2 occasionner la fin](https://ontome.net/ns/symogih/TyRo176_TyIn13_2) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn13'},
{'full':'| [TyRo176_TyIn12_2 occasionner la fin](https://ontome.net/ns/symogih/TyRo176_TyIn12_2) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn12'},
{'full':'| [TyRo16_TyIn7_2 être l\'origine](https://ontome.net/ns/symogih/TyRo16_TyIn7_2) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn7'},
{'full':'| [TyRo176_TyIn7_2 occasionner la fin](https://ontome.net/ns/symogih/TyRo176_TyIn7_2) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyIn7'},
{'full':'| [TyRo21_TyIn6_2 être concerné](https://ontome.net/ns/symogih/TyRo21_TyIn6_2) | [sym:NaPl](https://ontome.net/ns/symogih/NaPl) |  |  |', 'TyIn':'TyIn6'},
{'full':'| [TyRo3_TyIn3_2 être une création](https://ontome.net/ns/symogih/TyRo3_TyIn3_2) | [sym:InMaOb](https://ontome.net/ns/symogih/InMaOb) |  |  |', 'TyIn':'TyIn3'},
{'full':'| [TyRo39_TyCo1_1 avoir comme membre](https://ontome.net/ns/symogih/TyRo39_TyCo1_1) | [sym:StrCoAc](https://ontome.net/ns/symogih/StrCoAc) |  |  |', 'TyIn':'TyCo1'},
{'full':'| [TyRo39_TyCo1_2 avoir comme membre](https://ontome.net/ns/symogih/TyRo39_TyCo1_2) | [sym:Bibl](https://ontome.net/ns/symogih/Bibl) |  |  |', 'TyIn':'TyCo1'},
{'full':'| [TyRo8_TyCo4_1 localiser](https://ontome.net/ns/symogih/TyRo8_TyCo4_1) | [sym:ImCo](https://ontome.net/ns/symogih/ImCo) |  |  |', 'TyIn':'TyCo4'},
{'full':'| [TyRo8_TyCo4_2 localiser](https://ontome.net/ns/symogih/TyRo8_TyCo4_2) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |', 'TyIn':'TyCo4'}]

# %% [markdown]
# ## Trier les objets par issue

# %%
tyins = []

for item in contents:
    if item['TyIn'] not in tyins:
        tyins.append(item['TyIn'])

print(f"{len(tyins)} issues concernées :\n")
for tyin in sorted(tyins):
    print(tyin)
# Out:
# 42 issues concernées :
#
# TyCo1
# TyCo4
# TyIn102
# TyIn103
# TyIn104
# TyIn105
# TyIn107
# TyIn108
# TyIn12
# TyIn124
# TyIn125
# TyIn128
# TyIn13
# TyIn131
# TyIn138
# TyIn144
# TyIn147
# TyIn149
# TyIn150
# TyIn152
# TyIn156
# TyIn158
# TyIn165
# TyIn166
# TyIn168
# TyIn169
# TyIn26
# TyIn27
# TyIn3
# TyIn30
# TyIn51
# TyIn55
# TyIn59
# TyIn6
# TyIn66
# TyIn7
# TyIn79
# TyIn84
# TyIn85
# TyIn86
# TyIn90
# TyIn98

# %% [markdown]
# ## Mise en forme des tableaux par issue

# %%
for tyin in sorted(tyins):
    print(f"\n\n{tyin}")
    for item in contents:
        if item['TyIn'] == tyin:
            print(item['full'])
# Out:
# TyCo1
# | [TyRo39_TyCo1_1 avoir comme membre](https://ontome.net/ns/symogih/TyRo39_TyCo1_1) | [sym:StrCoAc](https://ontome.net/ns/symogih/StrCoAc) |  |  |
# | [TyRo39_TyCo1_2 avoir comme membre](https://ontome.net/ns/symogih/TyRo39_TyCo1_2) | [sym:Bibl](https://ontome.net/ns/symogih/Bibl) |  |  |
#
#
# TyCo4
# | [TyRo8_TyCo4_1 localiser](https://ontome.net/ns/symogih/TyRo8_TyCo4_1) | [sym:ImCo](https://ontome.net/ns/symogih/ImCo) |  |  |
# | [TyRo8_TyCo4_2 localiser](https://ontome.net/ns/symogih/TyRo8_TyCo4_2) | [sym:AbOb](https://ontome.net/ns/symogih/AbOb) |  |  |
#
#
# TyIn102
# | [TyRo13_TyIn102_1 être l'objet](https://ontome.net/ns/symogih/TyRo13_TyIn102_1) | [sym:InMaOb](https://ontome.net/ns/symogih/InMaOb) |  |  |
# | [TyRo13_TyIn102_2 être l'objet](https://ontome.net/ns/symogih/TyRo13_TyIn102_2) | [sym:TyIn103](https://ontome.net/ns/symogih/TyIn103) |  |  |
#
#
# TyIn103
# ...
